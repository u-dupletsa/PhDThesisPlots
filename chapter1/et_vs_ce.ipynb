# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# suppress warning outputs for using lal in jupuyter notebook
import warnings 
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")

import GWFish.modules as gw

# %%
# General settings
import matplotlib as mpl
mpl.rc_file('/Users/ulyanadupletsa/Documents/PhDThesisPlots/matplotlibrc')

mpl.rc('xtick', labelsize = 23) 
mpl.rc('ytick', labelsize = 23)

# %%
my_color = '#97a7a7'
my_color_darker = '#2f4f4f'
my_color2 = '#eba75f'
my_color2_darker = '#f6b26b'
my_fontsize = 25

# %%
psd_data_ET = gw.utilities.get_detector_psd('ET')
psd_data_CE = gw.utilities.get_detector_psd('CE1')

# %%
plt.loglog(psd_data_CE[:, 0], np.sqrt(psd_data_CE[:, 0] * psd_data_CE[:, 1]), color=my_color2_darker, linewidth=2.5, label='CE')
plt.loglog(psd_data_ET[:, 0], np.sqrt(psd_data_ET[:, 0] * psd_data_ET[:, 1]), color=my_color_darker, linewidth=2.5, label='ET_D')
plt.legend(fontsize=23, frameon=False, loc='upper center')
plt.ylim(1e-24, 1e-16)
plt.xlim(1, 50000)
plt.xlabel('Frequency [Hz]', fontsize=my_fontsize)
plt.ylabel('Characteristic Strain', fontsize=my_fontsize)
plt.savefig('plots/et_ce_cfr.pdf', bbox_inches='tight')
plt.show()
